# %%
# Data processing 
import pandas as pd
import numpy as np

import re
import json
from collections import Counter
from itertools import chain

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
#!pip install plotly

# %%
# Data vizualizations
import random
import plotly
from plotly import tools
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot 
init_notebook_mode(connected=True)
import plotly.offline as offline
import plotly.graph_objs as go
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
# Data Modeling
from sklearn import model_selection 
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.preprocessing import LabelEncoder
from sklearn.svm import SVC
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.multiclass import OneVsRestClassifier

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
train_data = pd.read_json('train.json') # store as dataframe objects
test_data = pd.read_json('test.json')

# %% [markdown]
# Проанализируем данные в датасете train_data

# %%
train_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 39774 entries, 0 to 39773
# Data columns (total 3 columns):
# cuisine        39774 non-null object
# id             39774 non-null int64
# ingredients    39774 non-null object
# dtypes: int64(1), object(2)
# memory usage: 932.3+ KB

# %%
train_data.shape #39774 rows, 3 colls
# Out:
# (39774, 3)

# %%
print("The training data consists of {} recipes".format(train_data.shape[0]))
# Out:
# The training data consists of 39774 recipes

# %%
print("First five elements in our training sample:")
train_data.head()
# Out:
# First five elements in our training sample:
#        cuisine     id                                        ingredients
# 0        greek  10259  [romaine lettuce, black olives, grape tomatoes...
# 1  southern_us  25693  [plain flour, ground pepper, salt, tomatoes, g...
# 2     filipino  20130  [eggs, pepper, salt, mayonaise, cooking oil, g...
# 3       indian  22213                [water, vegetable oil, wheat, salt]
# 4       indian  13162  [black pepper, shallots, cornflour, cayenne pe...

# %%
train_data["ingredients"][0]
# Out:
# ['romaine lettuce',
#  'black olives',
#  'grape tomatoes',
#  'garlic',
#  'pepper',
#  'purple onion',
#  'seasoning',
#  'garbanzo beans',
#  'feta cheese crumbles']

# %% [markdown]
# Проанализируем данные в датасете test_data

# %%
test_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9944 entries, 0 to 9943
# Data columns (total 2 columns):
# id             9944 non-null int64
# ingredients    9944 non-null object
# dtypes: int64(1), object(1)
# memory usage: 155.5+ KB

# %%
test_data.shape
# Out:
# (9944, 2)

# %%
print("The training data consists of {} recipes".format(test_data.shape[0]))
# Out:
# The training data consists of 9944 recipes

# %%
print("First five elements in our test sample:")
test_data.head()
# Out:
# First five elements in our test sample:
#       id                                        ingredients
# 0  18009  [baking powder, eggs, all-purpose flour, raisi...
# 1  28583  [sugar, egg yolks, corn starch, cream of tarta...
# 2  41580  [sausage links, fennel bulb, fronds, olive oil...
# 3  29752  [meat cuts, file powder, smoked sausage, okra,...
# 4  35687  [ground black pepper, salt, sausage casings, l...

# %% [markdown]
# Таким образом, мы имеем тренировочную выборку, содержащую следующие данные:
#     id рецепта
#     список ингредиентов
#     тип кухни, к которому рецепт относится
#
# Задача: предсказать тип кухни, к которому относится рецепт. Таким образом, нам нужно решить задачу классификации, которая предварительно требует анализа содержания датасета и создания модели

# %% [markdown]
# Рассмотрим более подробно исследуемые данные

# %%
for i in train_data.cuisine.unique():
    print(i)
# Out:
# greek
# southern_us
# filipino
# indian
# jamaican
# spanish
# italian
# mexican
# chinese
# british
# thai
# vietnamese
# cajun_creole
# brazilian
# french
# japanese
# irish
# korean
# moroccan
# russian

# %%
print("Number of cuisine categories: {}".format(len(train_data.cuisine.unique())))
# Out:
# Number of cuisine categories: 20

# %% [markdown]
# Мы получили, что у нас больше, чем 2 целевые переменные.
# В данном случае имеет место многоклассовая классификация.

# %%
'Simple function for random colours generation'
def random_colours(number_of_colors):
    colors = []
    for i in range (number_of_colors):
        colors.append("#" + ''.join([random.choice('0123456789ABCDEF') for j in range(6)]))
    return colors

# %% [markdown]
# Создадим таблицу с инормацией о количестве раз, сколько каждая кухня представлена в тренировочнй выборке

# %%
trace = go.Table(
                header = dict(values=['Cuisine','Number of recipes'], fill = dict(color=['#EABEB0']), align = ['left'] * 4),
                         cells = dict(values = [train_data.cuisine.value_counts().index, train_data.cuisine.value_counts()],
                                      align = ['left'] * 4))

layout = go.Layout(title='Number of recipes in each cuisine category',
                   titlefont = dict(size = 20),
                   width=500, height=650, 
                   paper_bgcolor =  'rgba(0,0,0,0)',
                   plot_bgcolor = 'rgba(0,0,0,0)',
                   autosize = False,
                   margin=dict(l=30,r=30,b=1,t=50,pad=1)  )
data = [trace]
fig = dict(data=data, layout=layout)
iplot(fig)
# Out:
# <div>
#
#
#             <div id="4dde6788-7117-4e7d-b9bf-c234af20c4a3" class="plotly-graph-div" style="height:650px; width:500px;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("4dde6788-7117-4e7d-b9bf-c234af20c4a3")) {
#                     Plotly.newPlot(
#                         '4dde6788-7117-4e7d-b9bf-c234af20c4a3',
#                         [{"cells": {"align": ["left", "left", "left", "left"], "values": [["italian", "mexican", "southern_us", "indian", "chinese", "french", "cajun_creole", "thai", "japanese", "greek", "spanish", "korean", "vietnamese", "moroccan", "british", "filipino", "irish", "jamaican", "russian", "brazilian"], [7838, 6438, 4320, 3003, 2673, 2646, 1546, 1539, 1423, 1175, 989, 830, 825, 821, 804, 755, 667, 526, 489, 467]]}, "header": {"align": ["left", "left", "left", "left"], "fill": {"color": ["#EABEB0"]}, "values": ["Cuisine", "Number of recipes"]}, "type": "table", "uid": "9e9d7561-9870-4b29-bbdf-1c18c77f28dc"}],
#                         {"autosize": false, "height": 650, "margin": {"b": 1, "l": 30, "pad": 1, "r": 30, "t": 50}, "paper_bgcolor": "rgba(0,0,0,0)", "plot_bgcolor": "rgba(0,0,0,0)", "title": {"font": {"size": 20}, "text": "Number of recipes in each cuisine category"}, "width": 500},
#                         {"showLink": false, "linkText": "Export to plot.ly", "plotlyServerURL": "https://plot.ly", "responsive": true}
#                     ).then(function(){
#
# var gd = document.getElementById('4dde6788-7117-4e7d-b9bf-c234af20c4a3');
# var x = new MutationObserver(function (mutations, observer) {{
#         var display = window.getComputedStyle(gd).display;
#         if (!display || display === 'none') {{
#             console.log([gd, 'removed!']);
#             Plotly.purge(gd);
#             observer.disconnect();
#         }}
# }});
#
# // Listen for the removal of the full notebook cells
# var notebookContainer = gd.closest('#notebook-container');
# if (notebookContainer) {{
#     x.observe(notebookContainer, {childList: true});
# }}
#
# // Listen for the clearing of the current output cell
# var outputEl = gd.closest('.output');
# if (outputEl) {{
#     x.observe(outputEl, {childList: true});
# }}
#
#                         })
#                 };
#                 });
#             </script>
#         </div>

# %% [markdown]
# Построим гистограмму с процентным распределением рецептов каждой кухни мира

# %%
#  Label distribution in percents
labelpercents = []
for i in train_data.cuisine.value_counts():
    percent = (i/sum(train_data.cuisine.value_counts()))*100
    percent = "%.2f" % percent
    percent = str(percent + '%')
    labelpercents.append(percent)

# %%
trace = go.Bar(
            x=train_data.cuisine.value_counts().values[::-1],
            y=[i for i in train_data.cuisine.value_counts().index][::-1],
            text=labelpercents[::-1],  textposition = 'outside', 
            orientation = 'h',marker = dict(color = random_colours(20)))
layout = go.Layout(
                   title='Number of recipes in each cuisine category',
                   titlefont = dict(size = 25),
                   width=1000, height=450, 
                   plot_bgcolor = 'rgba(0,0,0,0)',
                   paper_bgcolor = 'rgba(255, 219, 227, 0.88)',
                   margin=dict(l=75,r=110,b=50,t=60),
                   )
data = [trace]
fig = dict(data=data, layout=layout)
iplot(fig, filename='horizontal-bar')
# Out:
# <div>
#
#
#             <div id="f04bdc34-d6ef-47c1-8c55-e89788d40fa5" class="plotly-graph-div" style="height:450px; width:1000px;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("f04bdc34-d6ef-47c1-8c55-e89788d40fa5")) {
#                     Plotly.newPlot(
#                         'f04bdc34-d6ef-47c1-8c55-e89788d40fa5',
#                         [{"marker": {"color": ["#FE0491", "#78B3E1", "#9B9E9F", "#DF349B", "#B72625", "#6DFD81", "#1287C0", "#A9F225", "#CB60D0", "#90F39F", "#A194D0", "#7BB1B5", "#1CE464", "#21519B", "#0C639A", "#CB3370", "#9AF105", "#113F63", "#2B0ACB", "#5ED153"]}, "orientation": "h", "text": ["1.17%", "1.23%", "1.32%", "1.68%", "1.90%", "2.02%", "2.06%", "2.07%", "2.09%", "2.49%", "2.95%", "3.58%", "3.87%", "3.89%", "6.65%", "6.72%", "7.55%", "10.86%", "16.19%", "19.71%"], "textposition": "outside", "type": "bar", "uid": "e2695851-622a-46d3-84c7-3639f9a62d11", "x": [467, 489, 526, 667, 755, 804, 821, 825, 830, 989, 1175, 1423, 1539, 1546, 2646, 2673, 3003, 4320, 6438, 7838], "y": ["brazilian", "russian", "jamaican", "irish", "filipino", "british", "moroccan", "vietnamese", "korean", "spanish", "greek", "japanese", "thai", "cajun_creole", "french", "chinese", "indian", "southern_us", "mexican", "italian"]}],
#                         {"height": 450, "margin": {"b": 50, "l": 75, "r": 110, "t": 60}, "paper_bgcolor": "rgba(255, 219, 227, 0.88)", "plot_bgcolor": "rgba(0,0,0,0)", "title": {"font": {"size": 25}, "text": "Number of recipes in each cuisine category"}, "width": 1000},
#                         {"showLink": false, "linkText": "Export to plot.ly", "plotlyServerURL": "https://plot.ly", "responsive": true}
#                     ).then(function(){
#
# var gd = document.getElementById('f04bdc34-d6ef-47c1-8c55-e89788d40fa5');
# var x = new MutationObserver(function (mutations, observer) {{
#         var display = window.getComputedStyle(gd).display;
#         if (!display || display === 'none') {{
#             console.log([gd, 'removed!']);
#             Plotly.purge(gd);
#             observer.disconnect();
#         }}
# }});
#
# // Listen for the removal of the full notebook cells
# var notebookContainer = gd.closest('#notebook-container');
# if (notebookContainer) {{
#     x.observe(notebookContainer, {childList: true});
# }}
#
# // Listen for the clearing of the current output cell
# var outputEl = gd.closest('.output');
# if (outputEl) {{
#     x.observe(outputEl, {childList: true});
# }}
#
#                         })
#                 };
#                 });
#             </script>
#         </div>

# %% [markdown]
# Из гистограммы видим, что самой популярной кухней является итальянская. Следует за ней Мексиканская и Южноамериканская. Эти рецепты составляют почти 50% всех рецептов.

# %% [markdown]
# Проанализируем длину рецептов в тренировочной выборке

# %%
print('Maximum Number of Ingredients in a Dish: ',train_data['ingredients'].str.len().max())
print('Minimum Number of Ingredients in a Dish: ',train_data['ingredients'].str.len().min())
# Out:
# Maximum Number of Ingredients in a Dish:  65
# Minimum Number of Ingredients in a Dish:  1

# %%
longrecipes = train_data[train_data['ingredients'].str.len() > 30]
print("Получается, что {} рецептов состоят из более чем 30 ингредиентов!".format(len(longrecipes)))
# Out:
# Получается, что 40 рецептов состоят из более чем 30 ингредиентов!

# %%
print("Рассмотрим самый длинный рецепт в тренировочной выборке:" + "\n")
print(str(list(longrecipes[longrecipes['ingredients'].str.len() == 65].ingredients.values)) + "\n")
print("Рецепт: " + str(list(longrecipes[longrecipes['ingredients'].str.len() == 65].cuisine)))
# Out:
# Рассмотрим самый длинный рецепт в тренировочной выборке:
#
# [['fettucine', 'fresh marjoram', 'minced garlic', 'olive oil', 'garlic powder', 'large eggs', 'Alfredo sauce', 'vegetable oil', 'cajun seasoning', 'shredded romano cheese', 'basil dried leaves', 'salt', 'cayenne pepper', 'scallions', 'red bell pepper', 'boneless skinless chicken breast halves', 'soba', 'pasta sauce', 'kosher salt', 'milk', 'fresh ginger', 'ground black pepper', 'flour', 'cooked chicken', 'coarse salt', 'lemon', 'diced tomatoes', 'garlic', 'rice vinegar', 'NeufchГўtel', 'garlic cloves', 'dried parsley', 'frozen artichoke hearts', 'penne', 'pepper', 'sweet onion', 'part-skim mozzarella cheese', 'parmigiano reggiano cheese', 'basil leaves', 'onion powder', 'red wine vinegar', 'red pepper flakes', 'orzo', 'crushed red pepper', 'all-purpose flour', 'freshly ground pepper', 'sliced mushrooms', 'panko breadcrumbs', 'plum tomatoes', 'fresh basil', 'fresh leav spinach', 'water', 'sun-dried tomatoes', 'ground pepper', 'grated parmesan cheese', 'boneless skinless chicken breasts', 'chicken cutlets', 'butter', 'multi-grain penne pasta', 'extra-virgin olive oil', 'cilantro leaves', 'green pepper', 'shredded mozzarella cheese', 'fresh parsley', 'spaghetti']]
#
# Рецепт: ['italian']

# %% [markdown]
# Исследуем рецепты, состоящие из 1 или 2 ингредиентов

# %%
shortrecipes = train_data[train_data['ingredients'].str.len() <= 2]
print("{} рецептов состоят из 1 или 2 продуктов!".format(len(shortrecipes)))
# Out:
# 215 рецептов состоят из 1 или 2 продуктов!

# %%
print("Исследуем самые короткие рецепты:" + "\n")
print(list(train_data[train_data['ingredients'].str.len() == 1].ingredients.values))
# Out:
# Исследуем самые короткие рецепты:
#
# [['sushi rice'], ['dried rice noodles'], ['plain low-fat yogurt'], ['unsalted butter'], ['udon'], ['sticky rice'], ['butter'], ['corn tortillas'], ['grained'], ['lemonade concentrate'], ['jasmine rice'], ['unsalted butter'], ['cherry tomatoes'], ['butter'], ['cumin seed'], ['haricots verts'], ['vegetable oil'], ['spanish chorizo'], ['sweetened condensed milk'], ['water'], ['phyllo'], ['unsalted butter']]

# %%
print("Соответственно, кухни мира, к которым эти рецепты принадлежат" + "\n")
print(list(train_data[train_data['ingredients'].str.len() == 1].cuisine.values))
# Out:
# Соответственно, кухни мира, к которым эти рецепты принадлежат
#
# ['japanese', 'vietnamese', 'indian', 'indian', 'japanese', 'thai', 'indian', 'mexican', 'thai', 'southern_us', 'thai', 'indian', 'italian', 'french', 'indian', 'french', 'mexican', 'spanish', 'spanish', 'japanese', 'greek', 'indian']

# %% [markdown]
# Таким образом, самый длинный рецепт (65 ингредиентов) принадлежит итальянской кухне.
#
# Самые короткие рецепты принадлежат азиатской культуре - кухням Индии, Японии.
# Некоторые из них, которые содержат только рис вполне возможны, но некоторые рецепты выглядят странно. Например, те, которые состоят только из воды и масла. Здесь уже имеем дело с зашумленными данными или технической ошибкой (в выборку попала только половина рецепта)

# %%
#Проианализируем длины рецептов каждой кухни мира
boxplotcolors = random_colours(21)
labels = [i for i in train_data.cuisine.value_counts().index][::-1]
data = []
for i in range(20):
    trace = go.Box(
    y=train_data[train_data['cuisine'] == labels[i]]['ingredients'].str.len(), name = labels[i],
    marker = dict(color = boxplotcolors[i]))
    data.append(trace)
layout = go.Layout(
    title = "Длины рецептов для каждой кухни"
)

fig = go.Figure(data=data,layout=layout)
iplot(fig, filename = "Box Plot Styling Outliers")
# Out:
# <div>
#
#
#             <div id="212d8fe6-5b88-47d7-8e4f-025421b79d00" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("212d8fe6-5b88-47d7-8e4f-025421b79d00")) {
#                     Plotly.newPlot(
#                         '212d8fe6-5b88-47d7-8e4f-025421b79d00',
#                         [{"marker": {"color": "#A60897"}, "name": "brazilian", "type": "box", "uid": "c58ea14f-9d68-4853-b545-840ae216c221", "y": [5, 17, 3, 4, 9, 14, 6, 4, 15, 17, 13, 9, 4, 9, 25, 2, 3, 6, 9, 18, 4, 4, 16, 4, 17, 4, 6, 10, 7, 12, 9, 9, 14, 20, 3, 9, 11, 12, 8, 9, 13, 11, 16, 5, 2, 4, 7, 7, 4, 6, 5, 6, 16, 3, 16, 5, 6, 12, 9, 6, 7, 8, 25, 16, 13, 8, 13, 9, 6, 13, 16, 16, 8, 3, 19, 9, 12, 6, 5, 10, 7, 8, 12, 29, 7, 14, 3, 9, 11, 15, 12, 15, 16, 13, 15, 6, 5, 9, 18, 17, 11, 11, 9, 6, 15, 7, 24, 9, 6, 9, 4, 14, 5, 15, 13, 5, 4, 10, 5, 10, 23, 11, 12, 4, 5, 11, 19, 15, 16, 10, 6, 4, 17, 6, 13, 3, 22, 10, 13, 5, 14, 15, 5, 7, 8, 9, 9, 5, 14, 4, 17, 11, 5, 10, 4, 2, 6, 22, 14, 13, 10, 14, 6, 6, 7, 11, 6, 16, 6, 15, 5, 3, 11, 17, 7, 6, 5, 15, 6, 11, 8, 18, 5, 8, 12, 7, 18, 5, 14, 8, 16, 10, 4, 4, 9, 14, 6, 15, 10, 12, 4, 9, 4, 5, 18, 17, 7, 5, 3, 15, 36, 3, 8, 7, 6, 7, 16, 6, 3, 9, 5, 10, 17, 10, 6, 4, 18, 14, 14, 16, 14, 5, 4, 9, 4, 11, 13, 6, 4, 13, 11, 6, 10, 11, 4, 11, 13, 3, 7, 6, 5, 9, 3, 12, 5, 6, 12, 12, 6, 4, 4, 17, 8, 4, 14, 6, 15, 6, 5, 14, 16, 14, 7, 13, 15, 4, 17, 9, 16, 15, 5, 19, 5, 16, 6, 6, 13, 3, 21, 18, 15, 4, 6, 4, 7, 6, 12, 5, 6, 17, 5, 5, 8, 14, 15, 3, 6, 14, 7, 17, 6, 13, 7, 3, 11, 5, 11, 3, 15, 11, 5, 5, 16, 4, 4, 11, 8, 17, 14, 6, 4, 7, 4, 4, 12, 4, 13, 3, 5, 12, 12, 5, 11, 10, 6, 5, 13, 10, 5, 8, 5, 11, 59, 15, 11, 12, 6, 4, 4, 11, 9, 6, 11, 6, 6, 15, 7, 3, 12, 4, 4, 4, 10, 19, 13, 16, 3, 8, 4, 4, 11, 11, 19, 5, 8, 5, 5, 6, 4, 3, 7, 13, 8, 5, 14, 18, 15, 8, 5, 12, 7, 12, 4, 5, 4, 4, 11, 6, 17, 4, 8, 5, 5, 14, 9, 10, 8, 14, 11, 6, 4, 18, 12, 14, 11, 18, 4, 11, 21, 15, 7, 6, 7, 4, 6, 11, 8, 3, 4, 12, 16, 10, 5, 13, 8, 16, 3, 11, 10, 3, 4, 7, 16, 5, 4, 5, 11, 7, 10, 5, 11, 13, 10, 4, 12, 4, 4]}, {"marker": {"color": "#ECB0FB"}, "name": "russian", "type": "box", "uid": "68ca1045-f851-4e82-b798-1934c928ff4f", "y": [4, 9, 10, 8, 7, 5, 6, 12, 9, 9, 8, 6, 12, 13, 10, 7, 7, 13, 3, 8, 13, 10, 9, 7, 13, 7, 9, 10, 16, 12, 14, 9, 14, 8, 8, 19, 4, 8, 8, 9, 9, 14, 9, 18, 5, 7, 4, 13, 7, 4, 5, 18, 9, 7, 12, 12, 8, 15, 8, 9, 16, 6, 7, 6, 15, 11, 14, 13, 6, 8, 11, 11, 11, 16, 9, 9, 11, 21, 2, 11, 11, 17, 10, 6, 9, 9, 11, 19, 5, 10, 9, 11, 8, 14, 10, 4, 6, 4, 16, 17, 13, 16, 17, 9, 3, 9, 8, 6, 9, 11, 7, 23, 8, 15, 11, 6, 13, 7, 8, 24, 6, 14, 14, 17, 14, 9, 13, 9, 12, 13, 14, 6, 11, 8, 14, 7, 7, 3, 11, 8, 12, 10, 11, 5, 16, 5, 10, 10, 7, 7, 9, 15, 8, 12, 9, 9, 9, 7, 7, 16, 11, 10, 11, 7, 10, 8, 8, 7, 14, 5, 16, 6, 8, 10, 14, 7, 16, 7, 9, 20, 17, 9, 3, 10, 10, 8, 12, 11, 14, 11, 14, 24, 11, 5, 4, 6, 7, 9, 12, 4, 9, 9, 12, 10, 14, 15, 9, 19, 9, 6, 18, 13, 11, 11, 15, 18, 13, 12, 12, 18, 11, 7, 12, 8, 5, 11, 17, 14, 9, 3, 11, 9, 8, 11, 9, 8, 10, 8, 13, 17, 10, 9, 10, 17, 14, 18, 3, 15, 8, 6, 11, 12, 17, 5, 9, 12, 14, 16, 9, 12, 16, 14, 7, 4, 14, 7, 7, 6, 13, 13, 13, 10, 11, 10, 11, 21, 4, 12, 11, 5, 14, 15, 10, 14, 15, 8, 5, 10, 5, 16, 12, 8, 4, 9, 16, 12, 13, 7, 12, 14, 13, 13, 6, 8, 10, 6, 5, 18, 4, 9, 9, 9, 8, 14, 11, 7, 12, 25, 6, 7, 11, 3, 13, 13, 10, 10, 9, 14, 11, 14, 5, 12, 13, 11, 8, 6, 18, 20, 14, 13, 7, 6, 11, 9, 10, 8, 7, 5, 12, 6, 6, 4, 15, 6, 5, 9, 9, 10, 5, 9, 8, 12, 6, 18, 9, 14, 5, 7, 8, 9, 6, 6, 10, 18, 5, 8, 12, 9, 15, 10, 11, 12, 9, 8, 5, 6, 14, 6, 12, 7, 9, 11, 4, 12, 19, 12, 7, 9, 6, 15, 6, 13, 8, 12, 11, 9, 12, 11, 7, 8, 17, 8, 9, 6, 9, 3, 7, 13, 3, 9, 8, 25, 8, 16, 10, 14, 11, 6, 17, 10, 8, 12, 8, 7, 9, 12, 8, 5, 9, 9, 9, 8, 4, 17, 10, 16, 8, 3, 13, 13, 8, 8, 7, 7, 17, 9, 10, 9, 17, 9, 12, 15, 9, 8, 10, 10, 3, 13, 23, 10, 8, 13, 13, 10, 10, 7, 10, 6, 10, 6, 15, 10, 11, 8, 9, 10, 9, 17, 7]}, {"marker": {"color": "#168FF5"}, "name": "jamaican", "type": "box", "uid": "11755517-803d-46a4-9b21-a929d1765fdc", "y": [12, 22, 20, 20, 14, 16, 12, 17, 14, 17, 10, 4, 9, 14, 12, 11, 20, 16, 10, 4, 16, 18, 20, 16, 3, 9, 9, 17, 9, 11, 8, 6, 9, 23, 30, 10, 12, 13, 9, 11, 19, 19, 9, 16, 16, 11, 19, 17, 24, 5, 14, 21, 18, 5, 15, 17, 13, 12, 12, 6, 11, 10, 13, 14, 7, 11, 14, 25, 13, 15, 7, 19, 14, 16, 15, 11, ...

# %% [markdown]
# Рассмотрим наиболее часто встречающиееся игредиенты в тренировочной выборке.
# И те продукты, которые встречаются в выборке только 1 раз.

# %%
# список всех ингредиентов (с дубликатами)
allingredients = [] 
for item in train_data['ingredients']:
    for ingr in item:
        allingredients.append(ingr)

# %%
# Словарь, сколько раз каждый ингредиент встречается в выборке 
countingr = Counter()
for ingr in allingredients:
     countingr[ingr] += 1

# %%
print("Наиболее часто встречающиеся ингредиенты (первые 20): \n")
print(countingr.most_common(20))
print("\n")
# Out:
# Наиболее часто встречающиеся ингредиенты (первые 20):
#
# [('salt', 18049), ('onions', 7972), ('olive oil', 7972), ('water', 7457), ('garlic', 7380), ('sugar', 6434), ('garlic cloves', 6237), ('butter', 4848), ('ground black pepper', 4785), ('all-purpose flour', 4632), ('pepper', 4438), ('vegetable oil', 4385), ('eggs', 3388), ('soy sauce', 3296), ('kosher salt', 3113), ('green onions', 3078), ('tomatoes', 3058), ('large eggs', 2948), ('carrots', 2814), ('unsalted butter', 2782)]

# %%
print("Общее число уникальных ингредиентов = {}.".format(len(countingr)))
# Out:
# Общее число уникальных ингредиентов = 6714.

# %%
# выделим 20 наиболее популярных ингредиентов и построим их гистограмму
mostcommon = countingr.most_common(20)
mostcommoningr = [i[0] for i in mostcommon]
mostcommoningr_count = [i[1] for i in mostcommon]

# %%
trace = go.Bar(
            x=mostcommoningr_count[::-1],
            y= mostcommoningr[::-1],
            orientation = 'h',marker = dict(color = random_colours(20),
))
layout = go.Layout(
    xaxis = dict(title= 'Number of occurences in all recipes (training sample)', ),
    yaxis = dict(title='Ingredient',),
    title= '20 Most Common Ingredients', titlefont = dict(size = 20),
    margin=dict(l=150,r=10,b=60,t=60,pad=5),
    width=800, height=500, 
)
data = [trace]
fig = go.Figure(data=data, layout=layout)
iplot(fig, filename='horizontal-bar')
# Out:
# <div>
#
#
#             <div id="1b35ed7e-37ba-4126-9d6d-2d80573deca2" class="plotly-graph-div" style="height:500px; width:800px;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("1b35ed7e-37ba-4126-9d6d-2d80573deca2")) {
#                     Plotly.newPlot(
#                         '1b35ed7e-37ba-4126-9d6d-2d80573deca2',
#                         [{"marker": {"color": ["#ECCFF6", "#EC962B", "#96B12B", "#F8A602", "#85F854", "#A56D44", "#E8BBBA", "#FE21DA", "#A88CD8", "#74B9BF", "#84EA61", "#BCCE29", "#1BC371", "#9B4AD8", "#23EFFA", "#9ACE5E", "#622957", "#80C1B7", "#6A1779", "#60AA8E"]}, "orientation": "h", "type": "bar", "uid": "c25d3ac0-2115-4494-9a4e-e8eebd77515f", "x": [2782, 2814, 2948, 3058, 3078, 3113, 3296, 3388, 4385, 4438, 4632, 4785, 4848, 6237, 6434, 7380, 7457, 7972, 7972, 18049], "y": ["unsalted butter", "carrots", "large eggs", "tomatoes", "green onions", "kosher salt", "soy sauce", "eggs", "vegetable oil", "pepper", "all-purpose flour", "ground black pepper", "butter", "garlic cloves", "sugar", "garlic", "water", "olive oil", "onions", "salt"]}],
#                         {"height": 500, "margin": {"b": 60, "l": 150, "pad": 5, "r": 10, "t": 60}, "title": {"font": {"size": 20}, "text": "20 Most Common Ingredients"}, "width": 800, "xaxis": {"title": {"text": "Number of occurences in all recipes (training sample)"}}, "yaxis": {"title": {"text": "Ingredient"}}},
#                         {"showLink": false, "linkText": "Export to plot.ly", "plotlyServerURL": "https://plot.ly", "responsive": true}
#                     ).then(function(){
#
# var gd = document.getElementById('1b35ed7e-37ba-4126-9d6d-2d80573deca2');
# var x = new MutationObserver(function (mutations, observer) {{
#         var display = window.getComputedStyle(gd).display;
#         if (!display || display === 'none') {{
#             console.log([gd, 'removed!']);
#             Plotly.purge(gd);
#             observer.disconnect();
#         }}
# }});
#
# // Listen for the removal of the full notebook cells
# var notebookContainer = gd.closest('#notebook-container');
# if (notebookContainer) {{
#     x.observe(notebookContainer, {childList: true});
# }}
#
# // Listen for the clearing of the current output cell
# var outputEl = gd.closest('.output');
# if (outputEl) {{
#     x.observe(outputEl, {childList: true});
# }}
#
#                         })
#                 };
#                 });
#             </script>
#         </div>

# %% [markdown]
# Не удивительно, что соль, лук, оливковое масло, перец являются наиболее популярными. сложно представить рецепт без этих компонент. Так что можно сделать вывод, что они не обладают высокой информативностью для предсказания кухни мира, к которой принадлежат рецепты с этими компонентами.

# %% [markdown]
# Мы рассмотрели распредeление длин рецептов для каждой кухни. Теперь исследуем ингредиенты, которые специфичны для каждой из кухонь мира

# %%
allingredients = list(set(allingredients))

# %%
# Define a function that returns a dataframe with top unique ingredients in a given cuisine 
def cuisine_unique(cuisine, numingr, allingredients):
    '''
    Input:
        cuisine - cuisine category (ex. 'brazilian');
        numingr - how many specific ingredients do you want to see in the final result; 
        allingredients - list containing all unique ingredients in the whole sample.
    
    Output: 
        dataframe giving information about the name of the specific ingredient and how many times it occurs in the chosen cuisine (in descending order based on their counts)..

    '''
    allother = []
    for item in train_data[train_data.cuisine != cuisine]['ingredients']:
        for ingr in item:
            allother .append(ingr)
    allother  = list(set(allother ))
    
    specificnonly = [x for x in allingredients if x not in allother]
    
    mycounter = Counter()
    
    for item in train_data[train_data.cuisine == cuisine]['ingredients']:
        for ingr in item:
            mycounter[ingr] += 1
    keep = list(specificnonly)
    
    for word in list(mycounter):
        if word not in keep:
            del mycounter[word]
    
    cuisinespec = pd.DataFrame(mycounter.most_common(numingr), columns = ['ingredient','count'])
    
    return cuisinespec

# %%
cuisinespec= cuisine_unique('mexican', 10, allingredients)
print("Top 10 уникальных ингредиентов для мексиканской кухни:")
cuisinespec
# Out:
# Top 10 уникальных ингредиентов для мексиканской кухни:
#               ingredient  count
# 0          refried beans    250
# 1     taco seasoning mix    181
# 2    red enchilada sauce     65
# 3             taco sauce     63
# 4        poblano chilies     33
# 5      mexican chocolate     32
# 6   baked tortilla chips     31
# 7  green enchilada sauce     31
# 8           Mexican beer     30
# 9               chipotle     25

# %%
# Визуализация характерных ингредиентов для первых 10 кухонь
labels = [i for i in train_data.cuisine.value_counts().index][0:10]
totalPlot = 10
y = [[item]*2 for item in range(1,10)]
y = list(chain.from_iterable(y))
z = [1,2]*int((totalPlot/2))

fig = tools.make_subplots(rows= 5, cols=2, subplot_titles= labels, 
                          specs = [[{}, {}],[{}, {}],[{}, {}],[{}, {}],[{}, {}]],  
                          horizontal_spacing = 0.20)
traces = []
for i,e in enumerate(labels): 
    cuisinespec = cuisine_unique(e, 5, allingredients)
    trace = go.Bar(
            x = cuisinespec['count'].values[::-1],
            y = cuisinespec['ingredient'].values[::-1],
            orientation = 'h',marker = dict(color = random_colours(5),))
    traces.append(trace)

for t,y,z in zip(traces,y,z):
    fig.append_trace(t, y,z)

    fig['layout'].update(height=800, width=840,
    margin=dict(l=265,r=5,b=40,t=90,pad=5), showlegend=False, title='Ingredients used only in one cuisine')

iplot(fig, filename='horizontal-bar')
# Out:
# This is the format of your plot grid:
# [ (1,1) x1,y1 ]    [ (1,2) x2,y2 ]
# [ (2,1) x3,y3 ]    [ (2,2) x4,y4 ]
# [ (3,1) x5,y5 ]    [ (3,2) x6,y6 ]
# [ (4,1) x7,y7 ]    [ (4,2) x8,y8 ]
# [ (5,1) x9,y9 ]    [ (5,2) x10,y10 ]
# <div>
#
#
#             <div id="abb6d918-1cb6-481d-a803-1f9d215c831d" class="plotly-graph-div" style="height:800px; width:840px;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("abb6d918-1cb6-481d-a803-1f9d215c831d")) {
#                     Plotly.newPlot(
#                         'abb6d918-1cb6-481d-a803-1f9d215c831d',
#                         [{"marker": {"color": ["#F33856", "#4BF3A3", "#4AA66D", "#7DC367", "#BC212F"]}, "orientation": "h", "type": "bar", "uid": "43347bec-0a9a-4607-b4ad-a6f498b7000c", "x": [18, 20, 21, 26, 41], "xaxis": "x", "y": ["cheese ravioli", "potato gnocchi", "bulk italian sausag", "lasagna noodles, cooked and drained", "gnocchi"], "yaxis": "y"}, {"marker": {"color": ["#9BA7A6", "#DEFA05", "#351580", "#4A9FE3", "#A8483E"]}, "orientation": "h", "type": "bar", "uid": "9d0f78ee-71ee-4093-a8af-82ebfb57f2bf", "x": [33, 63, 65, 181, 250], "xaxis": "x2", "y": ["poblano chilies", "taco sauce", "red enchilada sauce", "taco seasoning mix", "refried beans"], "yaxis": "y2"}, {"marker": {"color": ["#8AD122", "#E8346B", "#78D691", "#8D173E", "#06587F"]}, "orientation": "h", "type": "bar", "uid": "2500683f-8d47-48c6-ad52-d4fe7506bf9d", "x": [6, 8, 10, 12, 14], "xaxis": "x3", "y": ["peaches in heavy syrup", "grit quick", "Nilla Wafers", "buttermilk biscuits", "collards"], "yaxis": "y3"}, {"marker": {"color": ["#761AF9", "#8E5391", "#AF5A64", "#68011F", "#401B2B"]}, "orientation": "h", "type": "bar", "uid": "54b44703-7979-4b46-b1ba-84483b28354b", "x": [19, 20, 23, 33, 36], "xaxis": "x4", "y": ["tandoori spices", "shahi jeera", "chana dal", "asafoetida powder", "fenugreek"], "yaxis": "y4"}, {"marker": {"color": ["#C16B50", "#7CACE1", "#375788", "#CC334C", "#C449A1"]}, "orientation": "h", "type": "bar", "uid": "fed3c10d-b58d-4dd0-9876-058d5c96e544", "x": [9, 9, 9, 17, 36], "xaxis": "x5", "y": ["shaoxing", "maltose", "dried black mushrooms", "ground sichuan pepper", "fermented black beans"], "yaxis": "y5"}, {"marker": {"color": ["#13AEBA", "#DF03E5", "#20E17F", "#52E77A", "#2419D5"]}, "orientation": "h", "type": "bar", "uid": "59450436-9dfc-4a9a-b6b6-6e800a273115", "x": [4, 4, 4, 4, 6], "xaxis": "x6", "y": ["goose fat", "snail shells", "knockwurst", "egg bread", "rouille"], "yaxis": "y6"}, {"marker": {"color": ["#F8CAFB", "#F7E5C8", "#4656CE", "#DC3444", "#F9144A"]}, "orientation": "h", "type": "bar", "uid": "61894a43-a960-4dc7-a0b1-2761f6d26868", "x": [3, 4, 6, 6, 8], "xaxis": "x7", "y": ["cajun style stewed tomatoes", "Pompeian Canola Oil and Extra Virgin Olive Oil", "Johnsonville Smoked Sausage", "Johnsonville Andouille", "gumbo file"], "yaxis": "y7"}, {"marker": {"color": ["#A50DD0", "#0AC454", "#5BD17B", "#E11B8D", "#ED3AF1"]}, "orientation": "h", "type": "bar", "uid": "17ba1503-8100-48a7-90e8-c4301b31f897", "x": [2, 3, 3, 5, 10], "xaxis": "x8", "y": ["cuttlefish balls", "panang curry paste", "Thai eggplants", "tom yum paste", "thai noodles"], "yaxis": "y8"}, {"marker": {"color": ["#14E478", "#46A4E7", "#352499", "#C92196", "#08A686"]}, "orientation": "h", "type": "bar", "uid": "19a0e194-b7f1-42ce-8109-f093eb3c8ae5", "x": [5, 5, 6, 14, 16], "xaxis": "x9", "y": ["yuzu", "sushi grade tuna", "mitsuba", "tonkatsu sauce", "dashi powder"], "yaxis": "y9"}, {"marker": {"color": ["#4580D5", "#E5D5A5", "#F29850", "#F3D268", "#2B3C50"]}, "orientation": "h", "type": "bar", "uid": "f7166349-1f16-4d85-a529-70830a2b6ccf", "x": [4, 5, 5, 9, 10], "xaxis": "x10", "y": ["sliced kalamata olives", "pita loaves", "greek-style vinaigrette", "kefalotyri", "ouzo"], "yaxis": "y10"}],
#                         {"annotations": [{"font": {"size": 16}, "showarrow": false, "text": "italian", "x": 0.2, "xanchor": "center", "xref": "paper", "y": 1.0, "yanchor": "bottom", "yref": "paper"}, {"font": {"size": 16}, "showarrow": false, "text": "mexican", "x": 0.8, "xanchor": "center", "xref": "paper", "y": 1.0, "yanchor": "bottom", "yref": "paper"}, {"font": {"size": 16}, "showarrow": false, "text": "southern_us", "x": 0.2, "xanchor": "center", "xref": "paper", "y": 0.78, "yanchor": "bottom", "yref": "paper"}, {"font": {"size": 16}, "showarrow": false, "text": "indian", "x": 0.8, "xanchor": "center", "xref": "paper", "y": 0.78, "yanchor": "bottom", "yref": "paper"}, {"font": {"size": 16}, "showarrow": false, "text": "chinese", "x": 0.2, "xanchor": "center", "xref": "paper", "y": 0.56, "yanchor": "bottom", "yref": "paper"}, {"font": {"size": 16}, "showarrow": false, "text": "french", "x": 0.8, "xanchor": "center", "xref": "paper", "y": 0.56, "yanchor": "bottom", "yref": "paper"}, {"font": {"size": 16}, "showarrow": false, "text": "cajun_creole", "x": 0.2, "xanchor": "center", "xref": "paper", "y": 0.33999999999999997, "yanchor": "bottom", "yref": "paper"}, {"font": {"size": 16}, "showarrow": false, "text": "thai", "x": 0.8, "xanchor": "center", "xref": "paper", "y": 0.33999999999999997, "yanchor": "bottom", "yref": "paper"}, {"font": {"size": 16}, "showarrow": false, "text": "japanese", "x": 0.2, "xanchor": "center", "xref": "paper", "y": 0.12, "yanchor": "bottom", "yref": "paper"}, {"font": {"size": 16}, "showarrow": false, "text": "greek", "x": 0.8, "xanchor": "center", "xref": "paper", "y": 0.12, "yanchor": "bottom", "yref": "paper"}], "height": 800, "margin": {"b": 40, "l": 265, "pad": 5, "r": 5, "t": 90}, "showlegend": false, "title": {"text": "Ingredients used only in one cuisine"}, "width": 840, "xaxis": {"anchor": "y", "domain": [0.0, 0.4]}, "xaxis10": {"anchor": "y10", "domain": [0.6000000000000001, 1.0]}, "xaxis2": {"anchor": "y2", "domain": [0.6000000000000001, 1.0]}, "xaxis3": {"anchor": "y3", "domain": [0.0, 0.4]}, "xaxis4": {"anchor": "y4", "domain": [0.6000000000000001, 1.0]}, "xaxis5": {"anchor": "y5", "domain": [0.0, 0.4]}, "xaxis6": {"anchor": "y6", "domain": [0.6000000000000001, 1.0]}, "xaxis7": {"anchor": "y7", "domain": [0.0, 0.4]}, "xaxis8": {"anchor": "y8", "domain": [0.6000000000000001, 1.0]}, "xaxis9": {"anchor": "y9", "domain": [0.0, 0.4]}, "yaxis": {"anchor": "x", "domain": [0.88, 1.0]}, "yaxis10": {"anchor": "x10", "domain": [0.0, 0.12]}, "yaxis2": {"anchor": "x2", "domain": [0.88, 1.0]}, "yaxis3": {"anchor": "x3", "domain": [0.66, 0.78]}, "yaxis4": {"anchor": "x4", "domain": [0.66, 0.78]}, "yaxis5": {"anchor": "x5", "domain": [0.44, 0.56]}, "yaxis6": {"anchor": "x6", "domain": [0.44, 0.56]}, "yaxis7": {"anchor": "x7", "domain": [0.22, 0.33999999999999997]}, "yaxis8": {"anchor": "x8", "domain": [0.22, 0.33999999999999997]}, "yaxis9": {"anchor": "x9", "domain": [0.0, 0.12]}},
#                         {"showLink": false, "linkText": "Export to plot.ly", "plotlyServerURL": "https://plot.ly", "responsive": true}
#                     ).then(function(){
#
# var gd = document.getElementById('abb6d918-1cb6-481d-a803-1f9d215c831d');
# var x = new MutationObserver(function (mutations, observer) {{
#         var display = window.getComputedStyle(gd).display;
#         if (!display || display === 'none') {{
#             console.log([gd, 'removed!']);
#             Plotly.purge(gd);
#             observer.disconnect();
#         }}
# }});
#
# // Listen for the removal of the full notebook cells
# var notebookContainer = gd.closest('#notebook-container');
# if (notebookContainer) {{
#     x.observe(notebookContainer, {childList: true});
# }}
#
# // Listen for the clearing of the current output cell
# var outputEl = gd.closest('.output');
# if (outputEl) {{
#     x.observe(outputEl, {childList: true});
# }}
#
#                         })
#                 };
#                 });
#             </script>
#         </div>

# %%
#для следующих 10 кухонь
labels = [i for i in train_data.cuisine.value_counts().index][10:20]
totalPlot = 10
y = [[item]*2 for item in range(1,10)]
y = list(chain.from_iterable(y))
z = [1,2]*int((totalPlot/2))

fig = tools.make_subplots(rows= 5, cols=2, subplot_titles= labels, specs = [[{}, {}],[{}, {}],[{}, {}],[{}, {}],[{}, {}]],  horizontal_spacing = 0.20)
traces = []
for i,e in enumerate(labels): 
    cuisinespec= cuisine_unique(e, 5, allingredients)
    trace = go.Bar(
            x= cuisinespec['count'].values[::-1],
            y=  cuisinespec['ingredient'].values[::-1],
            orientation = 'h',marker = dict(color = random_colours(5),))
    traces.append(trace)

for t,y,z in zip(traces,y,z):
    fig.append_trace(t, y,z)

    fig['layout'].update(height=800, width=840,
    margin=dict(l=170,r=5,b=40,t=90,pad=5), showlegend=False, title='Ingredients used only in one cuisine')

iplot(fig, filename='horizontal-bar')
# Out:
# This is the format of your plot grid:
# [ (1,1) x1,y1 ]    [ (1,2) x2,y2 ]
# [ (2,1) x3,y3 ]    [ (2,2) x4,y4 ]
# [ (3,1) x5,y5 ]    [ (3,2) x6,y6 ]
# [ (4,1) x7,y7 ]    [ (4,2) x8,y8 ]
# [ (5,1) x9,y9 ]    [ (5,2) x10,y10 ]
# <div>
#
#
#             <div id="5bd70ad0-6215-4010-a263-7157f56fd66f" class="plotly-graph-div" style="height:800px; width:840px;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("5bd70ad0-6215-4010-a263-7157f56fd66f")) {
#                     Plotly.newPlot(
#                         '5bd70ad0-6215-4010-a263-7157f56fd66f',
#                         [{"marker": {"color": ["#591F5C", "#E7CAC4", "#C1E72E", "#EBA2C1", "#8D499F"]}, "orientation": "h", "type": "bar", "uid": "51f3468c-9402-4a3e-9d3b-d20c05568483", "x": [3, 3, 4, 5, 6], "xaxis": "x", "y": ["low sodium vegetable juice", "quince paste", "paella rice", "rioja", "fideos"], "yaxis": "y"}, {"marker": {"color": ["#EE46B0", "#C3BAC3", "#3C8043", "#6AC750", "#7436DF"]}, "orientation": "h", "type": "bar", "uid": "8aa66d20-7c69-422d-b17d-597e1631ee4f", "x": [6, 6, 10, 10, 30], "xaxis": "x2", "y": ["kimchi juice", "doenzang", "korean chile paste", "rice syrup", "gochugaru"], "yaxis": "y2"}, {"marker": {"color": ["#3189BC", "#A24A1D", "#094519", "#960E6F", "#3BC7BC"]}, "orientation": "h", "type": "bar", "uid": "c400511f-6a11-48c3-b849-1e6aaf623ee8", "x": [3, 4, 5, 6, 9], "xaxis": "x3", "y": ["rice paddy herb", "asian basil", "nuoc nam", "dried wood ear mushrooms", "nuoc cham"], "yaxis": "y3"}, {"marker": {"color": ["#91CB5C", "#13FA0E", "#1A8956", "#C41F57", "#2E7E67"]}, "orientation": "h", "type": "bar", "uid": "521c8e23-91eb-434c-a1db-a91488cf56b4", "x": [2, 2, 3, 7, 8], "xaxis": "x4", "y": ["moroccan seasoning", "pickle wedges", "instant couscous", "merguez sausage", "whole wheat couscous"], "yaxis": "y4"}, {"marker": {"color": ["#0A4B5A", "#A007B3", "#39ECBF", "#F9D512", "#C8F320"]}, "orientation": "h", "type": "bar", "uid": "a208449a-fc6b-4fed-bc49-8133d1257a4f", "x": [4, 5, 5, 9, 12], "xaxis": "x5", "y": ["meringue nests", "porridge oats", "beef kidney", "stilton", "beef drippings"], "yaxis": "y5"}, {"marker": {"color": ["#7901D1", "#848146", "#C3A18F", "#FEBE97", "#30D58F"]}, "orientation": "h", "type": "bar", "uid": "798dd85e-9a18-45d6-ae45-e0eac4e8af56", "x": [3, 6, 10, 16, 17], "xaxis": "x6", "y": ["ampalaya", "Accent Seasoning", "lumpia skins", "lumpia wrappers", "calamansi juice"], "yaxis": "y6"}, {"marker": {"color": ["#B5D90C", "#6BCD21", "#F97CAB", "#5C1294", "#6FD8EB"]}, "orientation": "h", "type": "bar", "uid": "fed2855e-f6d0-4893-afd7-9a32eee7de04", "x": [2, 2, 3, 5, 7], "xaxis": "x7", "y": ["instant pudding mix", "black pudding", "Kerrygold Pure Irish Butter", "soda bread", "irish bacon"], "yaxis": "y7"}, {"marker": {"color": ["#600213", "#6AF16E", "#1245A3", "#A22481", "#8F30BE"]}, "orientation": "h", "type": "bar", "uid": "d4218a73-12db-441a-b3ad-bf0e02a83803", "x": [5, 6, 9, 9, 9], "xaxis": "x8", "y": ["jamaican jerk spice", "jerk sauce", "callaloo", "ackee", "jerk seasoning"], "yaxis": "y8"}, {"marker": {"color": ["#601A1F", "#7648A6", "#5B7875", "#4B62F9", "#6C17D9"]}, "orientation": "h", "type": "bar", "uid": "1375891e-2432-4103-91ac-cd0ce6219240", "x": [2, 2, 3, 3, 7], "xaxis": "x9", "y": ["parsley root", "herring fillets", "red russian kale", "kasha", "pierogi"], "yaxis": "y9"}, {"marker": {"color": ["#6B129D", "#DE6FBA", "#C0D5E1", "#AE97C6", "#BAEF3F"]}, "orientation": "h", "type": "bar", "uid": "3f31845d-1039-49a4-bb7a-2e07726a451d", "x": [9, 12, 12, 14, 70], "xaxis": "x10", "y": ["frozen banana", "manioc flour", "palm oil", "a\u0413\u00a7ai", "cachaca"], "yaxis": "y10"}],
#                         {"annotations": [{"font": {"size": 16}, "showarrow": false, "text": "spanish", "x": 0.2, "xanchor": "center", "xref": "paper", "y": 1.0, "yanchor": "bottom", "yref": "paper"}, {"font": {"size": 16}, "showarrow": false, "text": "korean", "x": 0.8, "xanchor": "center", "xref": "paper", "y": 1.0, "yanchor": "bottom", "yref": "paper"}, {"font": {"size": 16}, "showarrow": false, "text": "vietnamese", "x": 0.2, "xanchor": "center", "xref": "paper", "y": 0.78, "yanchor": "bottom", "yref": "paper"}, {"font": {"size": 16}, "showarrow": false, "text": "moroccan", "x": 0.8, "xanchor": "center", "xref": "paper", "y": 0.78, "yanchor": "bottom", "yref": "paper"}, {"font": {"size": 16}, "showarrow": false, "text": "british", "x": 0.2, "xanchor": "center", "xref": "paper", "y": 0.56, "yanchor": "bottom", "yref": "paper"}, {"font": {"size": 16}, "showarrow": false, "text": "filipino", "x": 0.8, "xanchor": "center", "xref": "paper", "y": 0.56, "yanchor": "bottom", "yref": "paper"}, {"font": {"size": 16}, "showarrow": false, "text": "irish", "x": 0.2, "xanchor": "center", "xref": "paper", "y": 0.33999999999999997, "yanchor": "bottom", "yref": "paper"}, {"font": {"size": 16}, "showarrow": false, "text": "jamaican", "x": 0.8, "xanchor": "center", "xref": "paper", "y": 0.33999999999999997, "yanchor": "bottom", "yref": "paper"}, {"font": {"size": 16}, "showarrow": false, "text": "russian", "x": 0.2, "xanchor": "center", "xref": "paper", "y": 0.12, "yanchor": "bottom", "yref": "paper"}, {"font": {"size": 16}, "showarrow": false, "text": "brazilian", "x": 0.8, "xanchor": "center", "xref": "paper", "y": 0.12, "yanchor": "bottom", "yref": "paper"}], "height": 800, "margin": {"b": 40, "l": 170, "pad": 5, "r": 5, "t": 90}, "showlegend": false, "title": {"text": "Ingredients used only in one cuisine"}, "width": 840, "xaxis": {"anchor": "y", "domain": [0.0, 0.4]}, "xaxis10": {"anchor": "y10", "domain": [0.6000000000000001, 1.0]}, "xaxis2": {"anchor": "y2", "domain": [0.6000000000000001, 1.0]}, "xaxis3": {"anchor": "y3", "domain": [0.0, 0.4]}, "xaxis4": {"anchor": "y4", "domain": [0.6000000000000001, 1.0]}, "xaxis5": {"anchor": "y5", "domain": [0.0, 0.4]}, "xaxis6": {"anchor": "y6", "domain": [0.6000000000000001, 1.0]}, "xaxis7": {"anchor": "y7", "domain": [0.0, 0.4]}, "xaxis8": {"anchor": "y8", "domain": [0.6000000000000001, 1.0]}, "xaxis9": {"anchor": "y9", "domain": [0.0, 0.4]}, "yaxis": {"anchor": "x", "domain": [0.88, 1.0]}, "yaxis10": {"anchor": "x10", "domain": [0.0, 0.12]}, "yaxis2": {"anchor": "x2", "domain": [0.88, 1.0]}, "yaxis3": {"anchor": "x3", "domain": [0.66, 0.78]}, "yaxis4": {"anchor": "x4", "domain": [0.66, 0.78]}, "yaxis5": {"anchor": "x5", "domain": [0.44, 0.56]}, "yaxis6": {"anchor": "x6", "domain": [0.44, 0.56]}, "yaxis7": {"anchor": "x7", "domain": [0.22, 0.33999999999999997]}, "yaxis8": {"anchor": "x8", "domain": [0.22, 0.33999999999999997]}, "yaxis9": {"anchor": "x9", "domain": [0.0, 0.12]}},
#                         {"showLink": false, "linkText": "Export to plot.ly", "plotlyServerURL": "https://plot.ly", "responsive": true}
#                     ).then(function(){
#
# var gd = document.getElementById('5bd70ad0-6215-4010-a263-7157f56fd66f');
# var x = new MutationObserver(function (mutations, observer) {{
#         var display = window.getComputedStyle(gd).display;
#         if (!display || display === 'none') {{
#             console.log([gd, 'removed!']);
#             Plotly.purge(gd);
#             observer.disconnect();
#         }}
# }});
#
# // Listen for the removal of the full notebook cells
# var notebookContainer = gd.closest('#notebook-container');
# if (notebookContainer) {{
#     x.observe(notebookContainer, {childList: true});
# }}
#
# // Listen for the clearing of the current output cell
# var outputEl = gd.closest('.output');
# if (outputEl) {{
#     x.observe(outputEl, {childList: true});
# }}
#
#                         })
#                 };
#                 });
#             </script>
#         </div>

# %% [markdown]
# __Feature Engineering & Data Modeling__

# %%
# Dataset Preparation
print ("Read Dataset ... ")
def read_dataset(path):
    return json.load(open(path)) 

train = read_dataset('train.json')
test = read_dataset('test.json')
# Out:
# Read Dataset ...

# %% [markdown]
# Для решения задачи классификации любой текст необходимо закодировать и представить в виде последовательности чисел.
# Выполняем задачу в несколько этапов:
# 1. приводим рецепты к нижнему регистру и соединяем ингредиенты в предложение
# 2. используем метод Tfidf-Vectorizer, список предложений пробразуем в матрицу, состоящую из чисел, которые соответствует встречаемости слов в каждом предложении

# %%
print ("Приводим тренировочную и тестовую выборки к нижнему регистру ... ")
def generate_text(data):
    text_data = [" ".join(doc['ingredients']).lower() for doc in data]
    return text_data
# Out:
# Приводим тренировочную и тестовую выборки к нижнему регистру ...

# %%
train_text = generate_text(train)
test_text = generate_text(test)
target = [doc['cuisine'] for doc in train]

# %%
# Feature Engineering 
print ("TF-IDF ... ")
tfidf = TfidfVectorizer(binary = True)
def tfidf_features(txt, flag):
    if flag == "train":
        x = tfidf.fit_transform(txt)
    else:
        x = tfidf.transform(txt)
    x = x.astype('float16')
    return x
# Out:
# TF-IDF ...

# %%
X = tfidf_features(train_text, flag = "train")
X_test = tfidf_features(test_text, flag = "test")

# %% [markdown]
# Для преобразования целевой переменной target используем метод LabelEncoding, с помощью которого каждому элементу (в нашем случае, кухне мира) ставится в соответствие число от 0 до 20.

# %%
# Label Encoding - Target 
print ("Закодируем целевую переменную тренировочной выборки ... ")
lb = LabelEncoder()
y = lb.fit_transform(target)
# Out:
# Закодируем целевую переменную тренировочной выборки ...

# %%
# Model Training 
print ("Обучим классификатор ... ")
#Support Vector machines Classifier
classifier = SVC(C=100, kernel='rbf', gamma=1, coef0=1,
                 shrinking=True, tol=0.001,  probability=False,  cache_size=200,
                 class_weight = None, verbose=False,  max_iter=-1, decision_function_shape=None,  random_state=None)

model = OneVsRestClassifier(classifier, n_jobs=4)
# Out:
# Обучим классификатор ...

# %%
model.fit(X, y)

# %%
# Predictions 
print ("Сделаем предсказание на тестовой выборке ... ")
y_test = model.predict(X_test)
y_pred = lb.inverse_transform(y_test)

# %%
# Submission
print ("Сгенерируем файл с ответами ... ")
test_id = [doc['id'] for doc in test]
sub = pd.DataFrame({'id': test_id, 'cuisine': y_pred}, columns=['id', 'cuisine'])
sub.to_csv('svm_output.csv', index=False)

# %%
test_data.head()
# Out:
#       id                                        ingredients
# 0  18009  [baking powder, eggs, all-purpose flour, raisi...
# 1  28583  [sugar, egg yolks, corn starch, cream of tarta...
# 2  41580  [sausage links, fennel bulb, fronds, olive oil...
# 3  29752  [meat cuts, file powder, smoked sausage, okra,...
# 4  35687  [ground black pepper, salt, sausage casings, l...

# %%
result = pd.read_csv('svm_output.csv', sep = ',')

# %%
result.head()
# Out:
#       id       cuisine
# 0  18009         irish
# 1  28583   southern_us
# 2  41580       italian
# 3  29752  cajun_creole
# 4  35687       italian
